# %% [markdown]
# # Evaluation Project - 1
# Baseball Case Study
# Problem Statement:
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# -- Output: Number of predicted wins (W)
#
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
#Checking for null values

df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# no null values present.

# %%
(df.loc[0:]=="").sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# no missing values.

# %% [markdown]
# # EDA

# %%
fig,ax=plt.subplots(figsize=(5,5))
ax.scatter(y=df["R"],x=df["HR"],color="firebrick",alpha=0.7)
ax.set_title("Home run VS Runs scored")
ax.set_xlabel("Home Run")
ax.set_ylabel("Runs scored")
plt.show()

# %% [markdown]
# There is an increase in the total runs scored as the total home runs increase.

# %%
fig,ax=plt.subplots(figsize=(5,5))
sns.scatterplot(data=df,x="AB",y="R")
ax.set_xlabel("At Bat")
ax.set_ylabel("Runs")
# Out:
# Text(0, 0.5, 'Runs')

# %% [markdown]
# There is no steady increase in runs as at bat increases. The slope of this curve although positive is flat.

# %%
fig,ax=plt.subplots(figsize=(5,5))
sns.scatterplot(data=df,x="W",y="ERA")
ax.set_xlabel("Total Wins")
ax.set_ylabel("Earned runs average")
# Out:
# Text(0, 0.5, 'Earned runs average')

# %% [markdown]
# This curve has a negative slope indicating as total wins increases ERA will decrease.

# %%
fig,ax=plt.subplots(figsize=(5,5))
sns.scatterplot(data=df,x="W",y="ER")
ax.set_xlabel("Total Wins")
ax.set_ylabel("Earned runs")
# Out:
# Text(0, 0.5, 'Earned runs')

# %% [markdown]
# Again, a negative slope is noticed implying with increase in earned runs the total win reduces.

# %%
fig,ax=plt.subplots(figsize=(5,5))
sns.scatterplot(data=df,x="RA",y="W")
ax.set_xlabel("Average runs")
ax.set_ylabel("Total win")
# Out:
# Text(0, 0.5, 'Total win')

# %% [markdown]
# With the increase in average runs there is a decrease in total wins.

# %%
fig,ax=plt.subplots(figsize=(5,5))
sns.scatterplot(data=df,x="SV",y="W")
ax.set_xlabel("Saves")
ax.set_ylabel("Total win")
# Out:
# Text(0, 0.5, 'Total win')

# %% [markdown]
# It can be noted from the curve that saves(sv) is proportional to total win(w). As W increases Sv has also increased.

# %%
fig,ax=plt.subplots(figsize=(5,5))
sns.scatterplot(data=df,x="RA",y="ER")
ax.set_xlabel("Average runs")
ax.set_ylabel("Earned runs")
# Out:
# Text(0, 0.5, 'Earned runs')

# %% [markdown]
# As average runs increases ER also increases steadily.

# %%
fig,ax=plt.subplots(figsize=(5,5))
sns.scatterplot(data=df,x="RA",y="ERA")
ax.set_xlabel("Average runs")
ax.set_ylabel("Earned runs Average")
# Out:
# Text(0, 0.5, 'Earned runs Average')

# %% [markdown]
# As average runs increases ERA also increases steadily.

# %%
fig,ax=plt.subplots(figsize=(6,7))
sns.kdeplot(data=df,x="E")
sns.kdeplot(data=df,x="W",shade=True)
ax.set_xlabel("Error/Wins")
# Out:
# Text(0.5, 0, 'Error/Wins')

# %% [markdown]
# Total wins and error have similar distribution. Wins is more normally distributed then Errors.

# %% [markdown]
# As per baseball statics, XBH – Extra base hits: total hits greater than singles
# XBH = 2B + 3B + HR

# %%
df["XBH"]=df["2B"]+df["3B"]+df["HR"]

#batting average
df["BA"]=df["H"]/df["AB"]

#at bat per home run
df["ABH"]=df["AB"]/df["HR"]

#strike out to walk ratio
df["KBB"]=df["SO"]/df["BB"]
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB  ...   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  ...  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  ...  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  ...  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  ...  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  ...  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  ...  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  ...  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  ...  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  ...  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  ...  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  ...  680  4.24   5
# ...

# %%
fig,ax=plt.subplots(figsize=(5,5))
sns.scatterplot(data=df,x="XBH",y="R")
ax.set_xlabel("Extra base hits")
ax.set_ylabel("Runs")
# Out:
# Text(0, 0.5, 'Runs')

# %% [markdown]
# As XBH increases Runs scored has also increases.

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.subplots(figsize=(20,20))
sns.heatmap(df.corr(), annot=True, linewidth=0.8, linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
#
# W is highly correlated with SV (0.67)
#
# RA, ER and ERA have a correlation with W = 0.8 indicating multi-colinearity.
#
# RA, ER and ERA have a correlation of close to 1 with eachother.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
#  17  XBH     30 non-null     int64
#  18  BA      30 non-null     float64
#  19  ABH     30 non-null     float64
#  20  KBB     30 non-null     float64
# dtypes: float64(4), int64(17)
# ...

# %% [markdown]
# Most features in the dataset are of int type. Only ERA is float.

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB  ...  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000  ...
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  ...
# std    10.452355   31.823309   57.053725   103.75947   22.815225  ...
# min    13.000000  100.000000  375.000000   973.00000   44.000000  ...
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=15)
plt.yticks(fontsize=12)
plt.title("Variables Summary")
plt.show()

# %% [markdown]
# Most features are not normally distributed.

# %% [markdown]
# # Checking for outliers and skewness

# %%
collist=df.columns.values
ncol=15 #no.of columns and rows to display the graphs i.e max col and max row
nrows=10
plt.figure(figsize=(ncol,3*ncol))
for i in range (0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(y=df[collist[i]],color="orange",orient="v")
    plt.tight_layout()

# %% [markdown]
#     R, ERA, SHO,SV, E,ABH and XBH have outliers.

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# XBH   -0.419998
# BA     0.651283
# ABH    0.515088
# KBB    0.073916
# dtype: float64

# %%
plt.figure(figsize=[30,35])
for i,column in enumerate (df.columns):
    plt.subplot(5,5,i+1)
    sns.kdeplot(x=df[column])

# %% [markdown]
#      Most features have skewness present.

# %%
import numpy as np 

df["R"]=np.sqrt(df["R"])
df.skew()
# Out:
# W      0.047089
# R      0.968676
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# XBH   -0.419998
# BA     0.651283
# ABH    0.515088
# KBB    0.073916
# dtype: float64

# %% [markdown]
# # Data Cleaning

# %%
df=df.drop(["2B","3B","HR"],axis=1) #because XBH is the sum of all three (XBH is the sum of 2B,3B and HR)
df
# Out:
#       W          R    AB     H   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0    95  26.907248  5575  1497  383   973  104  641  601  3.73   2    8  56
# 1    83  26.381812  5467  1349  439  1264   70  700  653  4.07   2   12  45
# 2    81  25.865034  5439  1395  533  1157   86  640  584  3.67  11   10  38
# 3    76  24.939928  5533  1381  404  1231   68  701  643  3.98   7    9  37
# 4    74  26.248809  5605  1515  455  1259   83  803  746  4.64   7   12  35
# 5    93  29.849623  5509  1480  570  1151   88  670  609  3.80   7   10  34
# 6    87  27.640550  5567  1397  554  1227   63  698  652  4.03   3    4  48
# 7    81  26.702060  5485  1370  418  1331   44  693  646  4.05   0   10  43
# 8    80  25.377155  5485  1383  436  1310   87  642  604  3.74   1   12  60
# 9    78  27.349589  5640  1495  478  1148   71  753  694  4.31   3   10  40
# 10   88  27.404379  5511  1419  503  1233  101  733  680  4.24   5    9  45
# ...

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]
from statsmodels.stats.outliers_influence import variance_inflation_factor 
def c_vif(x):
    vif=pd.DataFrame()
    vif["variables"]=x.columns
    vif["VIF"]=[variance_inflation_factor(x.values,i)for i in range(x.shape[1])]
    return(vif)

# %%
c_vif(x)
# Out:
#    variables            VIF
# 0          R    6744.603519
# 1         AB   11515.402879
# 2          H   79332.653080
# 3         BB    9595.021287
# 4         SO   11840.290353
# 5         SB      38.680380
# 6         RA   21242.070034
# 7         ER  182405.763116
# 8        ERA  116921.251297
# 9         CG       8.522865
# 10       SHO      37.677432
# 11        SV     259.795632
# 12         E     108.611560
# 13       XBH    1998.263755
# 14        BA  110262.462436
# 15       ABH     372.217737
# 16       KBB   10378.669190

# %%
df=df.drop(["ER","AB"],axis=1)  #have high vif values
x=df.iloc[:,1:]
y=df.iloc[:,0]
c_vif(x)
# Out:
#    variables           VIF
# 0          R   5984.211073
# 1          H  23967.750933
# 2         BB   4218.041868
# 3         SO   5956.953168
# 4         SB     27.807728
# 5         RA  10997.690924
# 6        ERA   8626.390567
# 7         CG      7.291993
# 8        SHO     24.891790
# 9         SV     99.389549
# 10         E     99.142421
# 11       XBH   1723.772922
# 12        BA  44014.510897
# 13       ABH    222.993248
# 14       KBB   4438.546362

# %%
df.corr()
# Out:
#             W         R         H        BB        SO        SB        RA  \
# W    1.000000  0.437042  0.037612  0.484342  0.111850 -0.157234 -0.812952
# R    0.437042  1.000000  0.483397  0.399370 -0.042807  0.081302 -0.046552
# H    0.037612  0.483397  1.000000 -0.118281 -0.398830  0.413444  0.224324
# BB   0.484342  0.399370 -0.118281  1.000000  0.233652 -0.098347 -0.416445
# SO   0.111850 -0.042807 -0.398830  0.233652  1.000000  0.030968 -0.129745
# SB  -0.157234  0.081302  0.413444 -0.098347  0.030968  1.000000  0.132290
# RA  -0.812952 -0.046552  0.224324 -0.416445 -0.129745  0.132290  1.000000
# ERA -0.819600 -0.053940  0.231172 -0.459832 -0.180368  0.126063  0.986674
# CG   0.080533  0.229258  0.147955  0.462478 -0.093418 -0.020783 -0.016659
# SHO  0.471805 -0.096409 -0.145559  0.426004  0.237721 -0.106563 -0.636862
# SV   0.666530 -0.088309 -0.130371  0.099445  0.126297 -0.183418 -0.616224
# E   -0.089485 -0.020312 -0.033173 -0.075685  0.155133  0.079149  0.198996
# ...

# %%
#removing outliers
import scipy
from scipy.stats import zscore 
z=np.abs(zscore(df))
z.shape
# Out:
# (30, 16)

# %%
threshold=3
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (30, 16)
# (29, 16)

# %%
#data loss
loss=(30-29)/30*100
loss
# Out:
# 3.3333333333333335

# %% [markdown]
# data loss is less than 10% we can proceed.

# %%
y=df_new.iloc[:,0]
x=df_new.iloc[:,1:]

# %%
df_new
# Out:
#       W          R     H   BB    SO   SB   RA   ERA  CG  SHO  SV    E  XBH  \
# 0    95  26.907248  1497  383   973  104  641  3.73   2    8  56   88  481
# 1    83  26.381812  1349  439  1264   70  700  4.07   2   12  45   86  477
# 2    81  25.865034  1395  533  1157   86  640  3.67  11   10  38   79  473
# 3    76  24.939928  1381  404  1231   68  701  3.98   7    9  37  101  423
# 4    74  26.248809  1515  455  1259   83  803  4.64   7   12  35   86  489
# 6    87  27.640550  1397  554  1227   63  698  4.03   3    4  48   93  503
# 7    81  26.702060  1370  418  1331   44  693  4.05   0   10  43   77  483
# 8    80  25.377155  1383  436  1310   87  642  3.74   1   12  60   95  477
# 9    78  27.349589  1495  478  1148   71  753  4.31   3   10  40   97  488
# 10   88  27.404379  1419  503  1233  101  733  4.24   5    9  45  119  483
# 11   86  27.000000  1363  486  1392  121  618  3.57   5   13  39   85  534
# ...

# %%
#removing skewness 
from sklearn.preprocessing import power_transform 
x=power_transform(x,method="yeo-johnson")
x
# Out:
# C:\Users\prank\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# array([[ 9.62515090e-01,  0.00000000e+00, -1.60519802e+00,
#         -2.55061247e+00,  9.36131648e-01, -6.60978697e-01,
#         -5.09292146e-01, -3.07098204e-01, -7.87002186e-01,
#          1.53275292e+00, -3.48265262e-01,  3.80104602e-01,
#          1.61541345e+00,  7.89756997e-01, -5.00385009e-01],
#        [ 2.98805818e-01,  0.00000000e+00, -4.62095966e-01,
#          9.36832915e-02, -5.16377335e-01,  1.60225829e-01,
#          2.41440214e-01, -3.07098204e-01,  2.36736538e-01,
#          3.12020186e-01, -5.40819806e-01,  2.34750904e-01,
#         -9.94707685e-01,  4.44180918e-02,  5.46310317e-01],
#        [-3.12134880e-01,  0.00000000e+00,  1.23209786e+00,
#         -9.35611465e-01,  2.25038365e-01, -6.74967476e-01,
#         -6.42097599e-01,  2.01131531e+00, -2.52844176e-01,
# ...

# %%
df_new.skew()
# Out:
# W      0.119013
# R     -0.300697
# H      0.783772
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# XBH   -1.013675
# BA     0.735645
# ABH    0.592076
# KBB    0.187317
# dtype: float64

# %% [markdown]
# # Preprocessing

# %%
from sklearn.preprocessing import MinMaxScaler
ms=MinMaxScaler()
x=ms.fit_transform(x)
x
# Out:
# array([[0.76265348, 0.        , 0.04858078, 0.        , 0.75316743,
#         0.36980291, 0.37917067, 0.3808006 , 0.30735723, 0.87953892,
#         0.41348317, 0.5382543 , 0.97038159, 0.63494964, 0.3719406 ],
#        [0.60541917, 0.        , 0.36894124, 0.49499186, 0.39079849,
#         0.55497703, 0.54117529, 0.3808006 , 0.55375063, 0.61322186,
#         0.36116914, 0.50984827, 0.2559691 , 0.4713738 , 0.66998735],
#        [0.46068585, 0.        , 0.84374811, 0.30231579, 0.57576535,
#         0.36664857, 0.35051186, 1.        , 0.43591836, 0.40026187,
#         0.14781417, 0.48225683, 0.67643869, 0.58768778, 0.        ],
#        [0.22470643, 0.        , 0.17258737, 0.43427304, 0.36534072,
#         0.5581003 , 0.49835565, 0.8005316 , 0.3731705 , 0.3661082 ,
#         0.68491843, 0.19949322, 0.40194918, 0.65223524, 0.80503113],
#        [0.56724878, 0.        , 0.45481432, 0.48571836, 0.54333307,
#         0.87421452, 0.81136213, 0.8005316 , 0.55375063, 0.29444737,
# ...

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
lr=LinearRegression()
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1, random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print("At random state=",i,'training accuracy =',r2_score(y_train,pred_train))
    print("At random state=",i,'testing accuracy =',r2_score(y_test,pred_test))
    print("\n")
# Out:
# At random state= 0 training accuracy = 0.9488311761395296
# At random state= 0 testing accuracy = 0.691160304195756
#
#
# At random state= 1 training accuracy = 0.9391179784293491
# At random state= 1 testing accuracy = 0.8843519295605853
#
#
# At random state= 2 training accuracy = 0.9353092176230607
# At random state= 2 testing accuracy = 0.6608273431436233
#
#
# At random state= 3 training accuracy = 0.9378047537096946
# At random state= 3 testing accuracy = 0.6211221257750497
#
#
# At random state= 4 training accuracy = 0.9523415179791789
# At random state= 4 testing accuracy = 0.185769412792952
#
#
# At random state= 5 training accuracy = 0.9483186824390993
# At random state= 5 testing accuracy = 0.7444139266922294
#
#
# At random state= 6 training accuracy = 0.945555102070751
# At random state= 6 testing accuracy = 0.7230025092494015
#
#
# At random state= 7 training accuracy = 0.9422054915243616
# At random state= 7 testing accuracy = 0.9018118869394748
#
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1, random_state=53)
lr.fit(x_train,y_train)
pred_train=lr.predict(x_train)
pred_test=lr.predict(x_test)
print('training accuracy =',r2_score(y_train,pred_train))
print('testing accuracy =',r2_score(y_test,pred_test))
# Out:
# training accuracy = 0.9408632821845896
# testing accuracy = 0.933130044321149

# %%
for i in range(2,11):
    rf_cv=cross_val_score(lr,x,y,cv=i)
    rfs=rf_cv.mean()
    print("Score =",rfs*100,"at cv =",i)
# Out:
# Score = -1287.7206498051391 at cv = 2
# Score = 28.15443996605671 at cv = 3
# Score = 49.344811918521664 at cv = 4
# Score = 33.68908048471673 at cv = 5
# Score = 33.92908466380995 at cv = 6
# Score = 17.011226753338747 at cv = 7
# Score = 20.880729260471593 at cv = 8
# Score = -791.9215308579843 at cv = 9
# Score = -412.42613436237525 at cv = 10

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score 
import warnings 
warnings.filterwarnings("ignore")

# %%
from sklearn.linear_model import Lasso

# %%
ls=Lasso()
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.4853828624013401

# %%
for i in range(2,11):
    rf_cv=cross_val_score(ls,x,y,cv=i)
    rfs=rf_cv.mean()
    print("Score =",rfs*100,"at cv =",i)
# Out:
# Score = 11.671360374461331 at cv = 2
# Score = -3.7718116068351035 at cv = 3
# Score = 27.302131224802995 at cv = 4
# Score = -3.74723469742025 at cv = 5
# Score = 11.650457393734804 at cv = 6
# Score = -1.3035412277482237 at cv = 7
# Score = -3.1462899831623483 at cv = 8
# Score = -2020.9336625887267 at cv = 9
# Score = -467.06979449054325 at cv = 10

# %% [markdown]
# # Ensemble

# %%
from sklearn.ensemble import AdaBoostRegressor
ad=AdaBoostRegressor()
ad.fit(x_train,y_train)
ad_pred=ad.predict(x_test)
ad_r2=r2_score(y_test,ad_pred)
ad_r2
# Out:
# 0.6421368804977473

# %%
for i in range(2,11):
    rf_cv=cross_val_score(ad,x,y,cv=i)
    rfs=rf_cv.mean()
    print("Score =",rfs*100,"at cv =",i)
# Out:
# Score = 13.103845677809723 at cv = 2
# Score = -22.429266020410022 at cv = 3
# Score = 55.61217407967786 at cv = 4
# Score = -87.2483270296248 at cv = 5
# Score = -42.28720529783943 at cv = 6
# Score = -49.237060915737544 at cv = 7
# Score = -34.53252344663321 at cv = 8
# Score = -1401.2110489502973 at cv = 9
# Score = -976.1477637053279 at cv = 10

# %% [markdown]
# # RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
rf_pred=rf.predict(x_test)
rf_r2=r2_score(y_test,rf_pred)
rf_r2
# Out:
# 0.6583985410856041

# %%
for i in range(2,11):
    rf_cv=cross_val_score(rf,x,y,cv=i)
    rfs=rf_cv.mean()
    print("Score =",rfs*100,"at cv =",i)
# Out:
# Score = 6.669003937389462 at cv = 2
# Score = -12.575689478698179 at cv = 3
# Score = 53.56709590569652 at cv = 4
# Score = -65.22543540919405 at cv = 5
# Score = -44.93425082831635 at cv = 6
# Score = -7.7357826676809545 at cv = 7
# Score = -17.731420691806214 at cv = 8
# Score = -1238.7491874390812 at cv = 9
# Score = -671.383383267082 at cv = 10

# %% [markdown]
# # Ridge

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=45)

# %%
from sklearn.linear_model import Ridge
regressor_rd = Ridge(normalize=True)
regressor_rd.fit(x_train,y_train)
y_pred_rd = regressor_rd.predict(x_test)
r2_score(y_test,y_pred_rd)
# Out:
# 0.6415346651337833

# %%
for i in range(2,9):
    rf_cv=cross_val_score(regressor_rd,x,y,cv=i)
    rfs=rf_cv.mean()
    print("Score =",rfs*100,"at cv =",i)
# Out:
# Score = 52.55157797143679 at cv = 2
# Score = 48.854419007386205 at cv = 3
# Score = 65.07782853923885 at cv = 4
# Score = 37.134007219754785 at cv = 5
# Score = 52.07719409716444 at cv = 6
# Score = 38.84183496900615 at cv = 7
# Score = 45.697532449844196 at cv = 8

# %%
rf_cv=cross_val_score(regressor_rd,x,y,cv=4)
rfs=rf_cv.mean()
print("CV Score =",rfs*100)
print("Accuracy_score =",r2_score(y_test,y_pred_rd)*100)
# Out:
# CV Score = 65.07782853923885
# Accuracy_score = 64.15346651337833

# %% [markdown]
# # XGB

# %%
from xgboost import XGBRegressor

# %%
xgb=XGBRegressor()
xgb.fit(x_train,y_train)
pred_xgb=xgb.predict(x_test)
r2_score(y_test,pred_xgb)
# Out:
# -0.332343187368902

# %%
for i in range(2,9):
    rf_cv=cross_val_score(xgb,x,y,cv=i)
    rfs=rf_cv.mean()
    print("Score =",rfs*100,"at cv =",i)
# Out:
# Score = 34.21214420727646 at cv = 2
# Score = -1.6792042076908986 at cv = 3
# Score = 44.61892933712647 at cv = 4
# Score = -129.52188602617704 at cv = 5
# Score = -92.74793989624425 at cv = 6
# Score = -55.00629231080077 at cv = 7
# Score = -130.8126359572607 at cv = 8

# %% [markdown]
# # KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
kNeighborsRegressor = KNeighborsRegressor()
kNeighborsRegressor.fit(x_train,y_train)
y_pred_kn = kNeighborsRegressor.predict(x_test)
r2_score(y_test,y_pred_kn)
# Out:
# 0.37725631768953016

# %%
for i in range(2,9):
    rf_cv=cross_val_score(kNeighborsRegressor,x,y,cv=i)
    rfs=rf_cv.mean()
    print("Score =",rfs*100,"at cv =",i)
# Out:
# Score = 28.3213907433256 at cv = 2
# Score = 23.30285101066759 at cv = 3
# Score = 45.68558841390078 at cv = 4
# Score = 18.2947349637406 at cv = 5
# Score = 25.33448771023296 at cv = 6
# Score = 21.386509738421765 at cv = 7
# Score = 14.974469893214826 at cv = 8

# %% [markdown]
# Ridge has the best accuracy close to 65 percent.

# %% [markdown]
# # Hyper paramter tuning

# %%
from sklearn.model_selection import GridSearchCV
param = {"solver":["auto","svd","cholesky","lsqr"],"max_iter":[50,100,150,200],"fit_intercept":[True,False],"alpha":[0.1,1,10]}
clf = GridSearchCV(Ridge(normalize=True),param_grid=param)

# %%
clf.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=Ridge(normalize=True),
#              param_grid={'alpha': [0.1, 1, 10], 'fit_intercept': [True, False],
#                          'max_iter': [50, 100, 150, 200],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr']})

# %%
print(clf.best_params_)
# Out:
# {'alpha': 0.1, 'fit_intercept': True, 'max_iter': 50, 'solver': 'svd'}

# %%
regressor_rd = Ridge(normalize=True,alpha=1,fit_intercept=True,max_iter=50,solver="svd",random_state=42)
regressor_rd.fit(x_train,y_train)
y_pred_rd = regressor_rd.predict(x_test)
r2_score(y_test,y_pred_rd)
# Out:
# 0.6415346651337832

# %%
rf_cv=cross_val_score(regressor_rd,x,y,cv=4)
rfs=rf_cv.mean()
print("CV Score =",rfs*100)
print("Accuracy_score =",r2_score(y_test,y_pred_rd)*100)
# Out:
# CV Score = 65.07782853923885
# Accuracy_score = 64.15346651337832

# %% [markdown]
# # Model Saving

# %%
import pickle 
filename= "Baseball.pkl"
pickle.dump(regressor_rd, open(filename,"wb"))

# %% [markdown]
# # Conclusion

# %%
a=np.array(y_test)
predicted = np.array(regressor_rd.predict(x_test))
df_com=pd.DataFrame({"original":a,"predicted":predicted}, index=range(len(a)))
df_com
# Out:
#    original  predicted
# 0        79  82.054039
# 1        80  87.203909
# 2        92  90.096397
# 3        68  68.289891
# 4        87  83.148234
# 5        88  80.745629

# %% [markdown]
# Vaster collection of data and more input features are the ways to improve accuracy.
